# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
toyota=pd.read_csv('/content/ToyotaCorolla.csv',encoding='latin1')

# %%
toyota
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
toyota.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %% [markdown]
# ### **EDA**

# %%
toyota=toyota[["Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]

# %%
toyota.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165
# 3  14950         26  48000  90  2000      3      5            210    1165
# 4  13750         30  38500  90  2000      3      5            210    1170

# %% [markdown]
# ### 1.Checking NULL Values

# %%
toyota.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1436 non-null   int64
#  1   Age_08_04      1436 non-null   int64
#  2   KM             1436 non-null   int64
#  3   HP             1436 non-null   int64
#  4   cc             1436 non-null   int64
#  5   Doors          1436 non-null   int64
#  6   Gears          1436 non-null   int64
#  7   Quarterly_Tax  1436 non-null   int64
#  8   Weight         1436 non-null   int64
# dtypes: int64(9)
# memory usage: 101.1 KB

# %% [markdown]
# As you can see on the above code there is 1436 entries and 1436 null values presented it Means **NO NULL VALUES** in the data.

# %% [markdown]
# ### 2 .Checking For Duplicate Values

# %%
toyota.duplicated().sum()
# Out:
# 1

# %%
toyota[toyota.duplicated()]
# Out:
#      Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 113  24950          8  13253  116  2000      5      5            234    1320

# %%
toyota.drop_duplicates(inplace=True)
# Out:
# <ipython-input-15-43e9bdc014ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toyota.drop_duplicates(inplace=True)

# %%
toyota.duplicated().sum()
# Out:
# 0

# %% [markdown]
# As we saw on the above we found One duplicated value and then we removed that duplicated values

# %%
#renaming the column names
toyota=toyota.rename({"Age_08_04":"Age",'Quarterly_Tax':"QT",'Weight':"WT"},axis=1)

# %%
toyota.head()
# Out:
#    Price  Age     KM  HP    cc  Doors  Gears   QT    WT
# 0  13500   23  46986  90  2000      3      5  210  1165
# 1  13750   23  72937  90  2000      3      5  210  1165
# 2  13950   24  41711  90  2000      3      5  210  1165
# 3  14950   26  48000  90  2000      3      5  210  1165
# 4  13750   30  38500  90  2000      3      5  210  1170

# %%
toyota.describe()
# Out:
#               Price          Age             KM           HP            cc  \
# count   1435.000000  1435.000000    1435.000000  1435.000000   1435.000000
# mean   10720.915679    55.980488   68571.782578   101.491986   1576.560976
# std     3608.732978    18.563312   37491.094553    14.981408    424.387533
# min     4350.000000     1.000000       1.000000    69.000000   1300.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.000000
# 50%     9900.000000    61.000000   63451.000000   110.000000   1600.000000
# 75%    11950.000000    70.000000   87041.500000   110.000000   1600.000000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.000000
#
#              Doors        Gears           QT           WT
# count  1435.000000  1435.000000  1435.000000  1435.000000
# mean      4.032753     5.026481    87.020209  1072.287108
# std       0.952667     0.188575    40.959588    52.251882
# min       2.000000     3.000000    19.000000  1000.000000
# ...

# %% [markdown]
# 2 .Checking Correlation

# %%
toyota.corr()
# Out:
#           Price       Age        KM        HP        cc     Doors     Gears  \
# Price  1.000000 -0.876273 -0.569420  0.314134  0.124375  0.183604  0.063831
# Age   -0.876273  1.000000  0.504575 -0.155293 -0.096549 -0.146929 -0.005629
# KM    -0.569420  0.504575  1.000000 -0.332904  0.103822 -0.035193  0.014890
# HP     0.314134 -0.155293 -0.332904  1.000000  0.035207  0.091803  0.209642
# cc     0.124375 -0.096549  0.103822  0.035207  1.000000  0.079254  0.014732
# Doors  0.183604 -0.146929 -0.035193  0.091803  0.079254  1.000000 -0.160101
# Gears  0.063831 -0.005629  0.014890  0.209642  0.014732 -0.160101  1.000000
# QT     0.211508 -0.193319  0.283312 -0.302287  0.305982  0.107353 -0.005125
# WT     0.575869 -0.466484 -0.023969  0.087143  0.335077  0.301734  0.021238
#
#              QT        WT
# Price  0.211508  0.575869
# Age   -0.193319 -0.466484
# KM     0.283312 -0.023969
# HP    -0.302287  0.087143
# cc     0.305982  0.335077
# Doors  0.107353  0.301734
# ...

# %%
sns.set_style(style='darkgrid')
sns.pairplot(toyota)

# %% [markdown]
# ### **Model Building:-**

# %%
from statsmodels.formula.api import ols

# %%
toyota.head()
# Out:
#    Price  Age     KM  HP    cc  Doors  Gears   QT    WT
# 0  13500   23  46986  90  2000      3      5  210  1165
# 1  13750   23  72937  90  2000      3      5  210  1165
# 2  13950   24  41711  90  2000      3      5  210  1165
# 3  14950   26  48000  90  2000      3      5  210  1165
# 4  13750   30  38500  90  2000      3      5  210  1170

# %%
model=ols("Price~Age+KM+HP+cc+	Doors+Gears+QT+WT",data=toyota).fit()

# %%
model.resid
# Out:
# 0      -3291.958871
# 1      -2503.800414
# 2      -2829.635210
# 3      -1455.789389
# 4      -2450.217277
#            ...
# 1431   -1294.255037
# 1432    2552.422658
# 1433      44.565598
# 1434   -1329.222041
# 1435   -3446.087526
# Length: 1435, dtype: float64

# %%
#Finding the Coefficinets
model.params
# Out:
# Intercept   -5472.540368
# Age          -121.713891
# KM             -0.020737
# HP             31.584612
# cc             -0.118558
# Doors          -0.920189
# Gears         597.715894
# QT              3.858805
# WT             16.855470
# dtype: float64

# %%
#Finding The tvalues and pvalues
(model.tvalues,np.round(model.pvalues,5))
# Out:
# (Intercept    -3.875273
#  Age         -46.551876
#  KM          -16.552424
#  HP           11.209719
#  cc           -1.316436
#  Doors        -0.023012
#  Gears         3.034563
#  QT            2.944198
#  WT           15.760663
#  dtype: float64,
#  Intercept    0.00011
#  Age          0.00000
#  KM           0.00000
#  HP           0.00000
#  cc           0.18824
#  Doors        0.98164
#  Gears        0.00245
#  QT           0.00329
#  WT           0.00000
#  dtype: float64)

# %%
#finding the accuracy by using the model
(model.rsquared,model.rsquared_adj)
#initially the accuracy is 86%
# Out:
# (0.8625200256947001, 0.8617487495415147)

# %%
#building SLR for finding "Insignificant Variable"
#insignificant Variables means the variable which is not contributing towards the prediction of prediction of price.
#as we saw above the CC and Doors are having higher pvalues so there is chance to these variable are insignificant variable.
#lets check
slr_d=ols("cc~ Doors",data=toyota).fit()

# %%
slr_d.params
# Out:
# Intercept    1434.182889
# Doors          35.305435
# dtype: float64

# %%
(slr_d.pvalues,slr_d.tvalues)
# Here We can See pvalue of "Doors" and "cc" become Significant.
# Out:
# (Intercept    6.784307e-150
#  Doors         2.661459e-03
#  dtype: float64,
#  Intercept    29.504524
#  Doors         3.009617
#  dtype: float64)

# %%
#lets check is any chances to insignificant towards price
slr_pc=ols("Price~ cc",data=toyota).fit()

# %%
slr_pc.params
# Out:
# Intercept    9053.536789
# cc              1.057605
# dtype: float64

# %%
(slr_pc.pvalues,slr_pc.tvalues)
# Here We can See pvalue of "cc" become Significant.
# Out:
# (Intercept    7.236022e-114
#  cc            2.292856e-06
#  dtype: float64,
#  Intercept    24.879592
#  cc            4.745039
#  dtype: float64)

# %%
#lets check is any chances to insignificant towards price
slr_pd=ols("Price~ Doors",data=toyota).fit()

# %%
slr_pd.params
# Out:
# Intercept    7916.145233
# Doors         695.497769
# dtype: float64

# %%
(slr_pd.pvalues,slr_pd.tvalues)
# Here We can See pvalue of "Doors" become Significant.
# Out:
# (Intercept    8.976407e-75
#  Doors        2.404166e-12
#  dtype: float64,
#  Intercept    19.421546
#  Doors         7.070520
#  dtype: float64)

# %% [markdown]
# ### **Model Validation Techniques**

# %%
toyota.head()
# Out:
#    Price  Age     KM  HP    cc  Doors  Gears   QT    WT
# 0  13500   23  46986  90  2000      3      5  210  1165
# 1  13750   23  72937  90  2000      3      5  210  1165
# 2  13950   24  41711  90  2000      3      5  210  1165
# 3  14950   26  48000  90  2000      3      5  210  1165
# 4  13750   30  38500  90  2000      3      5  210  1170

# %%
#There are two types of model validation Techniques are there
# 1 .Colliniearity Check   2. Residual Analysis
# 1 . Colliniearity Check (Colliniearity=1/(1-rsqured))

mlc_age=ols("Age~KM+HP+cc+Doors+Gears+QT+WT",data=toyota).fit().rsquared
vif_age=1/(1-mlc_age)

mlc_km=ols("KM~Age+HP+cc+Doors+Gears+QT+WT",data=toyota).fit().rsquared
vif_km=1/(1-mlc_km)

mlc_hp=ols("HP~Age+KM+cc+Doors+Gears+QT+WT",data=toyota).fit().rsquared
vif_hp=1/(1-mlc_hp)

mlc_cc=ols("cc~Age+KM+HP+Doors+Gears+QT+WT",data=toyota).fit().rsquared
vif_cc=1/(1-mlc_cc)

mlc_Doors=ols("Doors~Age+KM+HP+cc+Gears+QT+WT",data=toyota).fit().rsquared
vif_Doors=1/(1-mlc_Doors)

mlc_Gears=ols("Gears~Age+KM+HP+cc+Doors+QT+WT",data=toyota).fit().rsquared
vif_Gears=1/(1-mlc_Gears)

mlc_QT=ols("QT~Age+KM+HP+cc+Doors+Gears+WT",data=toyota).fit().rsquared
vif_QT=1/(1-mlc_QT)

mlc_WT=ols("WT~Age+KM+HP+cc+Doors+Gears+QT",data=toyota).fit().rsquared
vif_WT=1/(1-mlc_WT)

# %%
df={"Variables":["Age","KM","HP","cc","Doors","Gears","QT","WT"],"VIF_Score":[vif_age,vif_km,vif_hp,vif_cc,vif_Doors,vif_Gears,vif_QT,mlc_WT]}

# %%
vif_sc=pd.DataFrame(df)

# %%
vif_sc
# Here We can see That There is "No Multicollinearity" between The Indipendant Variables.Therefore None Of The Variables Are Predicted By the Other variables.
# Out:
#   Variables  VIF_Score
# 0       Age   1.876236
# 1        KM   1.757178
# 2        HP   1.419180
# 3        cc   1.163470
# 4     Doors   1.155890
# 5     Gears   1.098843
# 6        QT   2.295375
# 7        WT   0.597938

# %%
import statsmodels.api as sm

# %%
# 2. Residual Analysis
# Test for Normality of Residuals (Q-Q Plot) using residual model (model.resid).
sm.qqplot(model.resid,line='q')
plt.show()

# %%
#outliers detection from the above QQ-plot.
# in the above qq-plot we can observe that values above 6000 and below -6000 are outliers
list(np.where(model.resid>6000))
# Out:
# [array([109, 146, 522])]

# %%
list(np.where(model.resid<-6000))
# Out:
# [array([220, 600, 959])]

# %%
# Test for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vs standardized residual values).
#Homoscedasticity describes how the error term (the noise or disturbance between independent and dependent variables) is the same across the values of the independent variables.
#So, in homoscedasticity, the residual term is constant across observations, i.e., the variance is constant.
#In simple terms, as the value of the dependent variable changes, the error term does not vary much.

#In contrast, heteroscedasticity occurs when the size of the error term differs across the independent variable’s value.
# We can easily plots of Homoscedasticity and heteroscedasticity .In plot If we can its classic cone or fan shape it indicates heteroscedasticity.
def get_standardized_values(val):
  return (val-val.mean())/val.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),get_standardized_values(model.resid))
plt.title('Residual plot')
plt.xlabel('standardized fitted values')
plt.ylabel('standardized resid values')
plt.show()

# %%
# Test for errors or Residuals Vs Regressors or independent 'x' variables or predictors
from statsmodels.graphics.regressionplots import influence_plot

# %%
toyota.head()
# Out:
#    Price  Age     KM  HP    cc  Doors  Gears   QT    WT
# 0  13500   23  46986  90  2000      3      5  210  1165
# 1  13750   23  72937  90  2000      3      5  210  1165
# 2  13950   24  41711  90  2000      3      5  210  1165
# 3  14950   26  48000  90  2000      3      5  210  1165
# 4  13750   30  38500  90  2000      3      5  210  1170

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Age',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'HP',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'KM',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'cc',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Doors',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Gears',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'QT',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'WT',fig=fig)
plt.show()

# %% [markdown]
# ## Model Deletion Diagnostics (checking Outliers or Influencers)

# %% [markdown]
# Two Techniques : 1. Cook's Distance & 2. Leverage value

# %%
#1. Cook Distance
#get influience using cook distance
(c, _)=model.get_influence().cooks_distance

# %%
fig=plt.figure(figsize=(18,6))
plt.stem(np.arange(len(toyota)),np.round(c,3))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
np.argmax(c) , np.max(c)
# Out:
# (80, 78.72950582258932)

# %%
#fig,ax=plt.subplots(figsize=(20,20))
#fig=influence_plot(model,ax = ax)
influence_plot(model)

# %%
# 2. Leverage Value using High Influence Points : Points beyond Leverage_cutoff value are influencers.
# Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints

k = toyota.shape[1]
n = toyota.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff

# From the above , it is evident that points beyond leverage cutoff value=0.020905 are the outliers.
# Out:
# 0.020905923344947737

# %%
# Getting the Outlier data point index Values.
toyota[toyota.index.isin([80])]
# Out:
#     Price  Age     KM   HP     cc  Doors  Gears   QT    WT
# 80  18950   25  20019  110  16000      5      5  100  1180

# %% [markdown]
# ## **Improving the model**

# %%
toyota_new=toyota.copy()
toyota_new
# Out:
#       Price  Age     KM   HP    cc  Doors  Gears   QT    WT
# 0     13500   23  46986   90  2000      3      5  210  1165
# 1     13750   23  72937   90  2000      3      5  210  1165
# 2     13950   24  41711   90  2000      3      5  210  1165
# 3     14950   26  48000   90  2000      3      5  210  1165
# 4     13750   30  38500   90  2000      3      5  210  1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...   ...
# 1431   7500   69  20544   86  1300      3      5   69  1025
# 1432  10845   72  19000   86  1300      3      5   69  1015
# 1433   8500   71  17016   86  1300      3      5   69  1015
# 1434   7250   70  16916   86  1300      3      5   69  1015
# 1435   6950   76      1  110  1600      5      5   19  1114
#
# [1435 rows x 9 columns]

# %%
toyota_1=toyota_new.drop(toyota_new.index[[80]],axis=0).reset_index(drop=True)
toyota_1
# Out:
#       Price  Age     KM   HP    cc  Doors  Gears   QT    WT
# 0     13500   23  46986   90  2000      3      5  210  1165
# 1     13750   23  72937   90  2000      3      5  210  1165
# 2     13950   24  41711   90  2000      3      5  210  1165
# 3     14950   26  48000   90  2000      3      5  210  1165
# 4     13750   30  38500   90  2000      3      5  210  1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...   ...
# 1429   7500   69  20544   86  1300      3      5   69  1025
# 1430  10845   72  19000   86  1300      3      5   69  1015
# 1431   8500   71  17016   86  1300      3      5   69  1015
# 1432   7250   70  16916   86  1300      3      5   69  1015
# 1433   6950   76      1  110  1600      5      5   19  1114
#
# [1434 rows x 9 columns]

# %% [markdown]
# ## Model Deletion Diagnostics and Final Model

# %%
while np.max(c)>0.5 :
    model=ols('Price~Age+KM+HP+cc+Doors+Gears+QT+WT',data=toyota_1).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    toyota_1=toyota_1.drop(toyota_1.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    toyota_1
else:
    final_model=ols('Price~Age+KM+HP+cc+Doors+Gears+QT+WT',data=toyota_1).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.8882395145171204

# %%
if np.max(c)>0.5:
    model=ols('Price~Age+KM+HP+cc+Doors+Gears+QT+WT',data=toyota_1).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    toyota_1=toyota_1.drop(toyota_1.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    toyota_1
elif np.max(c)<0.5:
    final_model=ols('Price~Age+KM+HP+cc+Doors+Gears+QT+WT',data=toyota_1).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)

# Here The improved Model accuracy is 88.82%.
# Out:
# Thus model accuracy is improved to 0.8882395145171204

# %%
final_model.rsquared
# Out:
# 0.8882395145171204

# %% [markdown]
# ## **Model Prediction:**

# %%
# say New data for prediction is
new_data=pd.DataFrame({'Age':15,"KM":50000,"HP":90,"cc":1200,"Doors":4,"Gears":5,"QT":69,"WT":1012},index=[0])
new_data
# Out:
#    Age     KM  HP    cc  Doors  Gears  QT    WT
# 0   15  50000  90  1200      4      5  69  1012

# %%
# Manual Prediction of Price
final_model.predict(new_data)
# Out:
# 0    14544.230432
# dtype: float64

# %%
# Automatic Prediction of Price with 90.02% accurcy.
pred_y=final_model.predict(toyota_1)
pred_y
# Out:
# 0       16345.352610
# 1       15886.635544
# 2       16328.224968
# 3       15996.318854
# 4       15883.424182
#             ...
# 1426     9161.230587
# 1427     8536.091326
# 1428     8681.531063
# 1429     8793.668694
# 1430    10860.695492
# Length: 1431, dtype: float64
